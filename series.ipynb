# %%
import numpy as np
import pandas as pd

# %%
#string 
country = ['India' , 'Usa' , "Uk" , "Pakistan" , "srilanka"]

# %%
pd.Series(country)
# Out:
# 0       India
# 1         Usa
# 2          Uk
# 3    Pakistan
# 4    srilanka
# dtype: object

# %%
#integer
marks = [88 , 32 , 89 , 99 , 64 , 55 , 73]

pd.Series(marks)
# Out:
# 0    88
# 1    32
# 2    89
# 3    99
# 4    64
# 5    55
# 6    73
# dtype: int64

# %%
names = ["joy" , "roy" , "moi" , "loi" , "yoi" , "koi" , "toi"]
pd.Series(marks , index= names)
# Out:
# joy    88
# roy    32
# moi    89
# loi    99
# yoi    64
# koi    55
# toi    73
# dtype: int64

# %%
pd.Series(marks , index= names , name= 'MarksOfChemistry')
# Out:
# joy    88
# roy    32
# moi    89
# loi    99
# yoi    64
# koi    55
# toi    73
# Name: MarksOfChemistry, dtype: int64

# %%
#using disctionary

MyMarks = {
    'chemistry' : 92 ,
    "Maths" : 95 ,
    "Physics" : 93 , 
    "English" :89 ,
    "Art" : 100
}

# %%
MyMarksSeries = pd.Series(MyMarks , name= 'SKV')

# %%
# Series attributes

#size 
MyMarksSeries.size
# Out:
# 5

# %%
#name 
MyMarksSeries.name
# Out:
# 'SKV'

# %%
#index 
MyMarksSeries.index
# Out:
# Index(['chemistry', 'Maths', 'Physics', 'English', 'Art'], dtype='object')

# %%
#Values 
MyMarksSeries.values
# Out:
# array([ 92,  95,  93,  89, 100], dtype=int64)

# %%
#dtype 
MyMarksSeries.dtype
# Out:
# dtype('int64')

# %% [markdown]
# <h2>Series using read_csv</h2>

# %%
subs = pd.read_csv("subs.csv") # ==> It always gives us Dataframe as output by default

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
##If  the dataframe has only one column and u want to make series using pd.read_csv instead of dataframe .
## .squeeze()
subs = pd.read_csv("subs.csv").squeeze()

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
runs = pd.read_csv("kohli_ipl.csv").squeeze()

# %%
movies = pd.read_csv("bollywood.csv").squeeze()

# %%
runs
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
runs = pd.read_csv("kohli_ipl.csv" , index_col= 'match_no' ).squeeze()

# %%
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv("bollywood.csv" , index_col='movie')

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
#Series methods
#head & tail
#sample
#value_counts()
#sort_values()
#sort_index()
#count() --> It does not count the missing values .
#size()  --> It gives output including missing values. 
#describe --> It gives us the details of the series.

# %%
#head & tail

movies.head()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar

# %%
movies.head(7)
# Out:
#                                                       lead
# movie
# Uri: The Surgical Strike                     Vicky Kaushal
# Battalion 609                                  Vicky Ahuja
# The Accidental Prime Minister (film)           Anupam Kher
# Why Cheat India                              Emraan Hashmi
# Evening Shadows                           Mona Ambegaonkar
# Soni (film)                           Geetika Vidya Ohlyan
# Fraud Saiyaan                                 Arshad Warsi

# %%
movies.tail()
# Out:
#                                     lead
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Aankhen (2002 film)     Amitabh Bachchan
# Saathiya (film)             Vivek Oberoi
# Company (film)                Ajay Devgn
# Awara Paagal Deewana        Akshay Kumar

# %%
#sample()
movies.sample() # it randomly gives you any row form your datset
# Out:
#                     lead
# movie
# Hate Story 4  Lee Byford

# %%
#value_counts()
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
#sort_values()
runs.sort_values()
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
runs.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
#       ...
# 93       0
# 211      0
# 130      0
# 8        0
# 135      0
# Name: runs, Length: 215, dtype: int64

# %%
runs.sort_values(ascending=False).head(10)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
# 82      99
# 81      93
# 145     92
# 178     90
# 160     84
# Name: runs, dtype: int64

# %%
runs.sort_values(ascending=False).head(1).values
# Out:
# array([113], dtype=int64)

# %%
runs.sort_values(ascending=False).head(1).values[0]
# Out:
# 113

# %%
#the sort_values funtions doesn't changes in original series , if u want to do it u can use "inplace = true"

# %%
#sort_index() 
movies.sort_index()
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %%
#count()
runs.count()
# Out:
# 215

# %%
#sum()
subs.sum()
# Out:
# 49510

# %%
#product()
subs.product()
# Out:
# 0

# %%
#mean()
subs.mean()
# Out:
# 135.64383561643837

# %%
#mode()
subs.mode()
# Out:
# 0    105
# Name: Subscribers gained, dtype: int64

# %%
#mode
movies.mode().values[0][0]
# Out:
# 'Akshay Kumar'

# %%
# min/max 
subs.min()
# Out:
# 33

# %%
subs.max()
# Out:
# 396

# %%
#describe 
runs.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# <h3>Series Indexing</h3>

# %%
x = pd.Series([12 , 13 , 14 , 15 , 16 , 17])

# %%
x[0]
# Out:
# 12

# %%
# NOTE :- Series doesn't work on negative indecies. x[-1] will throw and error .

# %%
#Slicing 

runs[10 : 20]
# Out:
# match_no
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# 17    22
# 18    19
# 19    16
# 20    15
# Name: runs, dtype: int64

# %%
runs[-5 : ]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[::2]
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# The Accidental Prime Minister (film)       Anupam Kher
# Evening Shadows                       Mona Ambegaonkar
# Fraud Saiyaan                             Arshad Warsi
# Manikarnika: The Queen of Jhansi        Kangana Ranaut
# ...                                                ...
# Raaz (2002 film)                            Dino Morea
# Waisa Bhi Hota Hai Part II                Arshad Warsi
# Kaante                                Amitabh Bachchan
# Aankhen (2002 film)                   Amitabh Bachchan
# Company (film)                              Ajay Devgn
#
# [750 rows x 1 columns]

# %%
 #fancy indexing --> Indexing with labels
runs[[1 ,  3 , 4 , 6 , 50]]
# Out:
# match_no
# 1      1
# 3     13
# 4     12
# 6      9
# 50    11
# Name: runs, dtype: int64

# %% [markdown]
# <h3>Series with Python Functionalities</h3>

# %%
# len / type / dir / sorted / max / min 

# print (len(subs))
# print(type(subs))
# print(dir(subs))
#print(sorted(subs)) #--> Gives us the sorted series but in the form of List
# print(min(subs))
# print(max(subs))

# %%
# Type Conversion
list(MyMarksSeries)
# Out:
# [92, 95, 93, 89, 100]

# %%
dict(MyMarksSeries)
# Out:
# {'chemistry': 92, 'Maths': 95, 'Physics': 93, 'English': 89, 'Art': 100}

# %%
# membership operator
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
"Why Cheat India" in movies.index
# Out:
# True

# %%
"Amitabh Bachchan" in movies.values
# Out:
# True

# %%
#looping 

for i in movies.values :
    print(i)
# Out:
# ['Vicky Kaushal']
# ['Vicky Ahuja']
# ['Anupam Kher']
# ['Emraan Hashmi']
# ['Mona Ambegaonkar']
# ['Geetika Vidya Ohlyan']
# ['Arshad Warsi']
# ['Radhika Apte']
# ['Kangana Ranaut']
# ['Nawazuddin Siddiqui']
# ['Ali Asgar']
# ['Ranveer Singh']
# ['Prit Kamani']
# ['Ajay Devgn']
# ['Sushant Singh Rajput']
# ['Amitabh Bachchan']
# ['Abhimanyu Dasani']
# ['Talha Arshad Reshi']
# ['Nawazuddin Siddiqui']
# ['Garima Agarwal']
# ['Rasika Agashe']
# ['Barun Sobti']
# ['Akshay Kumar']
# ['Zaheer Iqbal']
# ['Vidyut Jammwal']
# ['Deepika Amin']
# ['Manav Kaul']
# ['Naseeruddin Shah']
# ['Varun Dhawan']
# ['Shreyas Talpade']
# ['Tiger Shroff']
# ['Boman Irani']
# ['Ajay Devgn']
# ['Arjun Kapoor']
# ['Gavie Chahal']
# ['Prabhu Deva']
# ['Shahid Kapoor']
# ['Ayushmann Khurrana']
# ['Anupam Kher']
# ['Karanvir Bohra']
# ['Hrithik Roshan']
# ['Jimmy Sheirgill']
# ['John Abraham']
# ['Rishi Kapoor']
# ['Kangana Ranaut']
# ['Natalia Janoszek']
# ['Diljit Dosanjh']
# ['Sidharth Malhotra']
# ...

# %%
for i in movies.index :
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic Operators(Broadcasting)
100 + MyMarksSeries
# Out:
# chemistry    192
# Maths        195
# Physics      193
# English      189
# Art          200
# Name: SKV, dtype: int64

# %%
# Relational Operators

runs >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# <h3>Boolean Indexing on Series</h3>

# %%
# Find no of 50's and 100's scored by kohli
runs[runs>=100]
# Out:
# match_no
# 120    100
# 123    108
# 126    109
# 128    113
# 164    100
# Name: runs, dtype: int64

# %%
runs[runs>=100].size
# Out:
# 5

# %%
# find actors who have done more than 20 movies

num_movies = movies.value_counts() 
num_movies
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy
